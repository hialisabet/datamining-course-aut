# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('_Datapreprocessing.csv', sep=",")
data
# Out:
#     Unnamed: 0    DataSource    Unnamed:1 https://data.worldbank.org  \
# 0            0          Data          NaN                       2016
# 1            1   CountryName  CountryCode          Population growth
# 2            2        Brazil          BRA                0.817555711
# 3            3   Switzerland          CHE                1.077221168
# 4            4       Germany          DEU                1.193866758
# 5            5       Denmark          DNK                0.834637611
# 6            6         Spain          ESP               -0.008048086
# 7            7        France          FRA                0.407491036
# 8            8         Japan          JPN               -0.115284177
# 9            9        Greece          GRC               -0.687542545
# 10          10          Iran          IRN                  1.1487886
# 11          11        Kuwait          KWT                2.924206194
# 12          12       Morocco          MAR                        NaN
# ...

# %%
data = pd.read_csv('_Datapreprocessing.csv', skiprows = 2, sep=",") #remove 2 rows
data
# Out:
#      1  CountryName CountryCode  Population growth  Total population  \
# 0    2       Brazil         BRA           0.817556      2.076529e+08
# 1    3  Switzerland         CHE           1.077221      8.372098e+06
# 2    4      Germany         DEU           1.193867      8.266768e+07
# 3    5      Denmark         DNK           0.834638               NaN
# 4    6        Spain         ESP          -0.008048      4.644396e+07
# 5    7       France         FRA           0.407491      6.689611e+07
# 6    8        Japan         JPN          -0.115284      1.269945e+08
# 7    9       Greece         GRC          -0.687543      1.074674e+07
# 8   10         Iran         IRN           1.148789      8.027743e+07
# 9   11       Kuwait         KWT           2.924206      4.052584e+06
# 10  12      Morocco         MAR                NaN      3.527679e+07
# 11  13      Nigeria         NGA           2.619034      1.859896e+08
# 12  14        Qatar         QAT           3.495070      2.569804e+06
# ...

# %%
data.columns
#we want delete the '1' columns, because we don't need it!
# Out:
# Index(['1', ' CountryName', 'CountryCode', 'Population growth',
#        'Total population', 'Area (sq. km)', 'International Visitors',
#        'Coronavirus Cases'],
#       dtype='object')

# %%
data.drop('1', axis = 1, inplace = True)
data
# Out:
#     CountryName CountryCode  Population growth  Total population  \
# 0        Brazil         BRA           0.817556      2.076529e+08
# 1   Switzerland         CHE           1.077221      8.372098e+06
# 2       Germany         DEU           1.193867      8.266768e+07
# 3       Denmark         DNK           0.834638               NaN
# 4         Spain         ESP          -0.008048      4.644396e+07
# 5        France         FRA           0.407491      6.689611e+07
# 6         Japan         JPN          -0.115284      1.269945e+08
# 7        Greece         GRC          -0.687543      1.074674e+07
# 8          Iran         IRN           1.148789      8.027743e+07
# 9        Kuwait         KWT           2.924206      4.052584e+06
# 10      Morocco         MAR                NaN      3.527679e+07
# 11      Nigeria         NGA           2.619034      1.859896e+08
# 12        Qatar         QAT           3.495070      2.569804e+06
# ...

# %%
data.isnull()
# Out:
#      CountryName  CountryCode  Population growth  Total population  \
# 0          False        False              False             False
# 1          False        False              False             False
# 2          False        False              False             False
# 3          False        False              False              True
# 4          False        False              False             False
# 5          False        False              False             False
# 6          False        False              False             False
# 7          False        False              False             False
# 8          False        False              False             False
# 9          False        False              False             False
# 10         False        False               True             False
# 11         False        False              False             False
# 12         False        False              False             False
# ...

# %%
data.isnull().sum()
# Out:
#  CountryName              0
# CountryCode               0
# Population growth         2
# Total population          1
# Area (sq. km)             1
# International Visitors    0
# Coronavirus Cases         0
# dtype: int64

# %%
data.dropna()
# Out:
#     CountryName CountryCode  Population growth  Total population  \
# 0        Brazil         BRA           0.817556      2.076529e+08
# 1   Switzerland         CHE           1.077221      8.372098e+06
# 2       Germany         DEU           1.193867      8.266768e+07
# 4         Spain         ESP          -0.008048      4.644396e+07
# 5        France         FRA           0.407491      6.689611e+07
# 6         Japan         JPN          -0.115284      1.269945e+08
# 7        Greece         GRC          -0.687543      1.074674e+07
# 8          Iran         IRN           1.148789      8.027743e+07
# 11      Nigeria         NGA           2.619034      1.859896e+08
# 12        Qatar         QAT           3.495070      2.569804e+06
# 14        India         IND           1.148215      1.324171e+09
#
#     Area (sq. km) International Visitors  Coronavirus Cases
# 0       8358140.0                      B              59324
# 1         39516.0                      B              29061
# ...

# %%
data.fillna(value = 0)
# Out:
#     CountryName CountryCode  Population growth  Total population  \
# 0        Brazil         BRA           0.817556      2.076529e+08
# 1   Switzerland         CHE           1.077221      8.372098e+06
# 2       Germany         DEU           1.193867      8.266768e+07
# 3       Denmark         DNK           0.834638      0.000000e+00
# 4         Spain         ESP          -0.008048      4.644396e+07
# 5        France         FRA           0.407491      6.689611e+07
# 6         Japan         JPN          -0.115284      1.269945e+08
# 7        Greece         GRC          -0.687543      1.074674e+07
# 8          Iran         IRN           1.148789      8.027743e+07
# 9        Kuwait         KWT           2.924206      4.052584e+06
# 10      Morocco         MAR           0.000000      3.527679e+07
# 11      Nigeria         NGA           2.619034      1.859896e+08
# 12        Qatar         QAT           3.495070      2.569804e+06
# ...

# %%
data['Total population'].fillna(value = data['Total population'].mean())
# Out:
# 0     2.076529e+08
# 1     8.372098e+06
# 2     8.266768e+07
# 3     1.565725e+08
# 4     4.644396e+07
# 5     6.689611e+07
# 6     1.269945e+08
# 7     1.074674e+07
# 8     8.027743e+07
# 9     4.052584e+06
# 10    3.527679e+07
# 11    1.859896e+08
# 12    2.569804e+06
# 13    9.903122e+06
# 14    1.324171e+09
# Name: Total population, dtype: float64

# %%
data['Area (sq. km)'].fillna(value = data['Area (sq. km)'].mean())
# Out:
# 0     8358140.0
# 1       39516.0
# 2      348900.0
# 3       42262.0
# 4      500210.0
# 5      547557.0
# 6      364560.0
# 7      128900.0
# 8     1628760.0
# 9     1193427.5
# 10     446300.0
# 11     910770.0
# 12      11610.0
# 13     407310.0
# 14    2973190.0
# Name: Area (sq. km), dtype: float64

# %%
data['Population growth'].fillna(value = data['Population growth'].mean())
# Out:
# 0     0.817556
# 1     1.077221
# 2     1.193867
# 3     0.834638
# 4    -0.008048
# 5     0.407491
# 6    -0.115284
# 7    -0.687543
# 8     1.148789
# 9     2.924206
# 10    1.142708
# 11    2.619034
# 12    3.495070
# 13    1.142708
# 14    1.148215
# Name: Population growth, dtype: float64

# %%
x = data.iloc[:, 0:6]
print(x)
y = data.iloc[:, 6]
print(y)
# Out:
#     CountryName CountryCode  Population growth  Total population  \
# 0        Brazil         BRA           0.817556      2.076529e+08
# 1   Switzerland         CHE           1.077221      8.372098e+06
# 2       Germany         DEU           1.193867      8.266768e+07
# 3       Denmark         DNK           0.834638               NaN
# 4         Spain         ESP          -0.008048      4.644396e+07
# 5        France         FRA           0.407491      6.689611e+07
# 6         Japan         JPN          -0.115284      1.269945e+08
# 7        Greece         GRC          -0.687543      1.074674e+07
# 8          Iran         IRN           1.148789      8.027743e+07
# 9        Kuwait         KWT           2.924206      4.052584e+06
# 10      Morocco         MAR                NaN      3.527679e+07
# 11      Nigeria         NGA           2.619034      1.859896e+08
# 12        Qatar         QAT           3.495070      2.569804e+06
# ...

# %%
#jaygozin kardne mean dar tamame maqadire NaN 
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer()
x.iloc[:, 2:5] = imputer.fit_transform(data.iloc[:, 2:5])
x
# Out:
#     CountryName CountryCode  Population growth  Total population  \
# 0        Brazil         BRA           0.817556      2.076529e+08
# 1   Switzerland         CHE           1.077221      8.372098e+06
# 2       Germany         DEU           1.193867      8.266768e+07
# 3       Denmark         DNK           0.834638      1.565725e+08
# 4         Spain         ESP          -0.008048      4.644396e+07
# 5        France         FRA           0.407491      6.689611e+07
# 6         Japan         JPN          -0.115284      1.269945e+08
# 7        Greece         GRC          -0.687543      1.074674e+07
# 8          Iran         IRN           1.148789      8.027743e+07
# 9        Kuwait         KWT           2.924206      4.052584e+06
# 10      Morocco         MAR           1.142708      3.527679e+07
# 11      Nigeria         NGA           2.619034      1.859896e+08
# 12        Qatar         QAT           3.495070      2.569804e+06
# ...

# %%
from sklearn.impute import KNNImputer

# %%
imputerr = KNNImputer(n_neighbors = 2)
x.iloc[:, 2:5] = imputerr.fit_transform(data.iloc[:, 2:5])
x
# Out:
#     CountryName CountryCode  Population growth  Total population  \
# 0        Brazil         BRA           0.817556      2.076529e+08
# 1   Switzerland         CHE           1.077221      8.372098e+06
# 2       Germany         DEU           1.193867      8.266768e+07
# 3       Denmark         DNK           0.834638      6.212341e+06
# 4         Spain         ESP          -0.008048      4.644396e+07
# 5        France         FRA           0.407491      6.689611e+07
# 6         Japan         JPN          -0.115284      1.269945e+08
# 7        Greece         GRC          -0.687543      1.074674e+07
# 8          Iran         IRN           1.148789      8.027743e+07
# 9        Kuwait         KWT           2.924206      4.052584e+06
# 10      Morocco         MAR           0.413295      3.527679e+07
# 11      Nigeria         NGA           2.619034      1.859896e+08
# 12        Qatar         QAT           3.495070      2.569804e+06
# ...
